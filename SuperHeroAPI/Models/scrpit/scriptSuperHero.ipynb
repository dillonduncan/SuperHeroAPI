-- %% [markdown]
-- # [SuperHeroes]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [SuperHeroes]    Script Date: 23/11/2023 7:59:29 ******/
CREATE DATABASE [SuperHeroes]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'SuperHeroes', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\SuperHeroes.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'SuperHeroes_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\SuperHeroes_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [SuperHeroes] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [SuperHeroes].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [SuperHeroes] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [SuperHeroes] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [SuperHeroes] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [SuperHeroes] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [SuperHeroes] SET ARITHABORT OFF 
GO
ALTER DATABASE [SuperHeroes] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [SuperHeroes] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [SuperHeroes] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [SuperHeroes] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [SuperHeroes] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [SuperHeroes] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [SuperHeroes] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [SuperHeroes] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [SuperHeroes] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [SuperHeroes] SET  DISABLE_BROKER 
GO
ALTER DATABASE [SuperHeroes] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [SuperHeroes] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [SuperHeroes] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [SuperHeroes] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [SuperHeroes] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [SuperHeroes] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [SuperHeroes] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [SuperHeroes] SET RECOVERY FULL 
GO
ALTER DATABASE [SuperHeroes] SET  MULTI_USER 
GO
ALTER DATABASE [SuperHeroes] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [SuperHeroes] SET DB_CHAINING OFF 
GO
ALTER DATABASE [SuperHeroes] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [SuperHeroes] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [SuperHeroes] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [SuperHeroes] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'SuperHeroes', N'ON'
GO
ALTER DATABASE [SuperHeroes] SET QUERY_STORE = ON
GO
ALTER DATABASE [SuperHeroes] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Acompanantes]

-- %%
USE [SuperHeroes]
GO

-- %%
/****** Object:  Table [dbo].[Acompanantes]    Script Date: 23/11/2023 7:59:29 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Acompanantes](
	[SuperheroeID] [int] NOT NULL,
	[AgrupacionesID] [int] NOT NULL,
 CONSTRAINT [PK_Acompanantes_1] PRIMARY KEY CLUSTERED 
(
	[SuperheroeID] ASC,
	[AgrupacionesID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Agrupaciones]

-- %%
/****** Object:  Table [dbo].[Agrupaciones]    Script Date: 23/11/2023 7:59:29 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agrupaciones](
	[AgrupacionesID] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [text] NULL,
	[Nombre_integrantes] [text] NULL,
 CONSTRAINT [PK_Agrupaciones] PRIMARY KEY CLUSTERED 
(
	[AgrupacionesID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Misiones]

-- %%
/****** Object:  Table [dbo].[Misiones]    Script Date: 23/11/2023 7:59:29 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Misiones](
	[Codigo_Mision] [int] IDENTITY(1,1) NOT NULL,
	[Descripcion] [nvarchar](255) NULL,
	[TipoID] [int] NOT NULL,
	[Estado_Mision] [text] NULL,
 CONSTRAINT [PK__Misiones__06370DAD83B9EB21] PRIMARY KEY CLUSTERED 
(
	[Codigo_Mision] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Misiones_Agrupaciones]

-- %%
/****** Object:  Table [dbo].[Misiones_Agrupaciones]    Script Date: 23/11/2023 7:59:29 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Misiones_Agrupaciones](
	[MisionesCodigo] [int] NOT NULL,
	[AgrupacionID] [int] NOT NULL,
	[FechaAsignacion] [date] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Superheroes]

-- %%
/****** Object:  Table [dbo].[Superheroes]    Script Date: 23/11/2023 7:59:29 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Superheroes](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](255) NULL,
	[AnioDebut] [int] NULL,
	[ContraseniaHero] [varchar](50) NULL,
	[PlanetaOrigenASuperHero] [nvarchar](255) NULL,
 CONSTRAINT [PK__Superher__3214EC277AFCDA26] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Superheroes_Misiones]

-- %%
/****** Object:  Table [dbo].[Superheroes_Misiones]    Script Date: 23/11/2023 7:59:29 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Superheroes_Misiones](
	[SuperheroeID] [int] NOT NULL,
	[MisionCodigo] [int] NOT NULL,
	[FechaAsignacion] [date] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Superheroes_Superpoderes]

-- %%
/****** Object:  Table [dbo].[Superheroes_Superpoderes]    Script Date: 23/11/2023 7:59:29 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Superheroes_Superpoderes](
	[SuperheroeID] [int] NOT NULL,
	[SuperpoderCodigo] [int] NOT NULL,
	[NivelPoder] [float] NULL,
PRIMARY KEY CLUSTERED 
(
	[SuperheroeID] ASC,
	[SuperpoderCodigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Superpoderes]

-- %%
/****** Object:  Table [dbo].[Superpoderes]    Script Date: 23/11/2023 7:59:29 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Superpoderes](
	[CodigoPoder] [int] IDENTITY(1,1) NOT NULL,
	[NombrePoder] [nvarchar](255) NULL,
 CONSTRAINT [PK__Superpod__06370DAD28F8E336] PRIMARY KEY CLUSTERED 
(
	[CodigoPoder] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoMision]

-- %%
/****** Object:  Table [dbo].[TipoMision]    Script Date: 23/11/2023 7:59:29 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoMision](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TipoMision] [nchar](10) NULL,
 CONSTRAINT [PK_TipoMision] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Acompanantes]

-- %%
INSERT [dbo].[Acompanantes] ([SuperheroeID], [AgrupacionesID]) VALUES (1, 1)
GO

-- %% [markdown]
-- # [dbo].[Agrupaciones]

-- %%
SET IDENTITY_INSERT [dbo].[Agrupaciones] ON 
INSERT [dbo].[Agrupaciones] ([AgrupacionesID], [Nombre], [Nombre_integrantes]) VALUES (1, N'Guerreros Z', N'Goku, Vegeta, Picolo, Gohan')
SET IDENTITY_INSERT [dbo].[Agrupaciones] OFF
GO

-- %% [markdown]
-- # [dbo].[Misiones]

-- %%
SET IDENTITY_INSERT [dbo].[Misiones] ON 
INSERT [dbo].[Misiones] ([Codigo_Mision], [Descripcion], [TipoID], [Estado_Mision]) VALUES (1, N'Salvar al planeta Namek de Freezer', 1, N'Incompleto')
INSERT [dbo].[Misiones] ([Codigo_Mision], [Descripcion], [TipoID], [Estado_Mision]) VALUES (2, N'Recoger las esferas del dragon', 2, N'Completado')
SET IDENTITY_INSERT [dbo].[Misiones] OFF
GO

-- %% [markdown]
-- # [dbo].[Superheroes]

-- %%
SET IDENTITY_INSERT [dbo].[Superheroes] ON 
INSERT [dbo].[Superheroes] ([ID], [Nombre], [AnioDebut], [ContraseniaHero], [PlanetaOrigenASuperHero]) VALUES (1, N'Goku', 1990, N'1990', N'Vegetta')
INSERT [dbo].[Superheroes] ([ID], [Nombre], [AnioDebut], [ContraseniaHero], [PlanetaOrigenASuperHero]) VALUES (2, N'Deadpool', 2000, N'2000', N'')
INSERT [dbo].[Superheroes] ([ID], [Nombre], [AnioDebut], [ContraseniaHero], [PlanetaOrigenASuperHero]) VALUES (3, N'Vegueta', 1990, N'1990', N'Vegetta')
INSERT [dbo].[Superheroes] ([ID], [Nombre], [AnioDebut], [ContraseniaHero], [PlanetaOrigenASuperHero]) VALUES (4, N'Picolo', 2000, N'2000', N'Namek')
INSERT [dbo].[Superheroes] ([ID], [Nombre], [AnioDebut], [ContraseniaHero], [PlanetaOrigenASuperHero]) VALUES (5, N'Gohan', 2010, NULL, NULL)
INSERT [dbo].[Superheroes] ([ID], [Nombre], [AnioDebut], [ContraseniaHero], [PlanetaOrigenASuperHero]) VALUES (6, N'BatMan', 1980, NULL, NULL)
INSERT [dbo].[Superheroes] ([ID], [Nombre], [AnioDebut], [ContraseniaHero], [PlanetaOrigenASuperHero]) VALUES (7, N'Robin', 1985, NULL, NULL)
INSERT [dbo].[Superheroes] ([ID], [Nombre], [AnioDebut], [ContraseniaHero], [PlanetaOrigenASuperHero]) VALUES (8, N'Superman', 1000, N'123', N'Krypton')
INSERT [dbo].[Superheroes] ([ID], [Nombre], [AnioDebut], [ContraseniaHero], [PlanetaOrigenASuperHero]) VALUES (9, N'Messi', 2004, N'2004', N'Planeta futbol')
INSERT [dbo].[Superheroes] ([ID], [Nombre], [AnioDebut], [ContraseniaHero], [PlanetaOrigenASuperHero]) VALUES (11, N'Geider', 1990, N'1990', N'Vegetta')
INSERT [dbo].[Superheroes] ([ID], [Nombre], [AnioDebut], [ContraseniaHero], [PlanetaOrigenASuperHero]) VALUES (13, N'Lilia', 190, N'1090', N'Jupiter')
INSERT [dbo].[Superheroes] ([ID], [Nombre], [AnioDebut], [ContraseniaHero], [PlanetaOrigenASuperHero]) VALUES (14, N'Dillon', 2005, N'12345', N'Marte')
SET IDENTITY_INSERT [dbo].[Superheroes] OFF
GO

-- %% [markdown]
-- # [dbo].[Superheroes_Misiones]

-- %%
INSERT [dbo].[Superheroes_Misiones] ([SuperheroeID], [MisionCodigo], [FechaAsignacion]) VALUES (1, 1, CAST(N'2023-11-10' AS Date))
INSERT [dbo].[Superheroes_Misiones] ([SuperheroeID], [MisionCodigo], [FechaAsignacion]) VALUES (2, 1, CAST(N'2023-11-10' AS Date))
GO

-- %% [markdown]
-- # [dbo].[Superheroes_Superpoderes]

-- %%
INSERT [dbo].[Superheroes_Superpoderes] ([SuperheroeID], [SuperpoderCodigo], [NivelPoder]) VALUES (1, 3, 100)
INSERT [dbo].[Superheroes_Superpoderes] ([SuperheroeID], [SuperpoderCodigo], [NivelPoder]) VALUES (2, 3, 10)
GO

-- %% [markdown]
-- # [dbo].[Superpoderes]

-- %%
SET IDENTITY_INSERT [dbo].[Superpoderes] ON 
INSERT [dbo].[Superpoderes] ([CodigoPoder], [NombrePoder]) VALUES (1, N'Velocidad')
INSERT [dbo].[Superpoderes] ([CodigoPoder], [NombrePoder]) VALUES (3, N'Super saiyajin 100')
INSERT [dbo].[Superpoderes] ([CodigoPoder], [NombrePoder]) VALUES (4, N'Teletransportacion')
SET IDENTITY_INSERT [dbo].[Superpoderes] OFF
GO

-- %% [markdown]
-- # [dbo].[TipoMision]

-- %%
SET IDENTITY_INSERT [dbo].[TipoMision] ON 
INSERT [dbo].[TipoMision] ([ID], [TipoMision]) VALUES (1, N'MSU       ')
INSERT [dbo].[TipoMision] ([ID], [TipoMision]) VALUES (2, N'MR        ')
SET IDENTITY_INSERT [dbo].[TipoMision] OFF
GO

-- %% [markdown]
-- # [UQ__Superher__75E3EFCF2C456150]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__Superher__75E3EFCF2C456150]    Script Date: 23/11/2023 7:59:29 ******/
ALTER TABLE [dbo].[Superheroes] ADD  CONSTRAINT [UQ__Superher__75E3EFCF2C456150] UNIQUE NONCLUSTERED 
(
	[Nombre] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Acompanantes_Agrupaciones]

-- %%
ALTER TABLE [dbo].[Acompanantes]  WITH CHECK ADD  CONSTRAINT [FK_Acompanantes_Agrupaciones] FOREIGN KEY([AgrupacionesID])
REFERENCES [dbo].[Agrupaciones] ([AgrupacionesID])
GO
ALTER TABLE [dbo].[Acompanantes] CHECK CONSTRAINT [FK_Acompanantes_Agrupaciones]
GO

-- %% [markdown]
-- # [FK_Acompanantes_Superheroes]

-- %%
ALTER TABLE [dbo].[Acompanantes]  WITH CHECK ADD  CONSTRAINT [FK_Acompanantes_Superheroes] FOREIGN KEY([SuperheroeID])
REFERENCES [dbo].[Superheroes] ([ID])
GO
ALTER TABLE [dbo].[Acompanantes] CHECK CONSTRAINT [FK_Acompanantes_Superheroes]
GO

-- %% [markdown]
-- # [FK_Misiones_TipoMision]

-- %%
ALTER TABLE [dbo].[Misiones]  WITH CHECK ADD  CONSTRAINT [FK_Misiones_TipoMision] FOREIGN KEY([TipoID])
REFERENCES [dbo].[TipoMision] ([ID])
GO
ALTER TABLE [dbo].[Misiones] CHECK CONSTRAINT [FK_Misiones_TipoMision]
GO

-- %% [markdown]
-- # [FK_Misiones_Agrupaciones_Agrupaciones]

-- %%
ALTER TABLE [dbo].[Misiones_Agrupaciones]  WITH CHECK ADD  CONSTRAINT [FK_Misiones_Agrupaciones_Agrupaciones] FOREIGN KEY([AgrupacionID])
REFERENCES [dbo].[Agrupaciones] ([AgrupacionesID])
GO
ALTER TABLE [dbo].[Misiones_Agrupaciones] CHECK CONSTRAINT [FK_Misiones_Agrupaciones_Agrupaciones]
GO

-- %% [markdown]
-- # [FK_Misiones_Agrupaciones_Misiones]

-- %%
ALTER TABLE [dbo].[Misiones_Agrupaciones]  WITH CHECK ADD  CONSTRAINT [FK_Misiones_Agrupaciones_Misiones] FOREIGN KEY([MisionesCodigo])
REFERENCES [dbo].[Misiones] ([Codigo_Mision])
GO
ALTER TABLE [dbo].[Misiones_Agrupaciones] CHECK CONSTRAINT [FK_Misiones_Agrupaciones_Misiones]
GO

-- %% [markdown]
-- # [FK__Superhero__Misio__5165187F]

-- %%
ALTER TABLE [dbo].[Superheroes_Misiones]  WITH CHECK ADD  CONSTRAINT [FK__Superhero__Misio__5165187F] FOREIGN KEY([MisionCodigo])
REFERENCES [dbo].[Misiones] ([Codigo_Mision])
GO
ALTER TABLE [dbo].[Superheroes_Misiones] CHECK CONSTRAINT [FK__Superhero__Misio__5165187F]
GO

-- %% [markdown]
-- # [FK__Superhero__Super__5070F446]

-- %%
ALTER TABLE [dbo].[Superheroes_Misiones]  WITH CHECK ADD  CONSTRAINT [FK__Superhero__Super__5070F446] FOREIGN KEY([SuperheroeID])
REFERENCES [dbo].[Superheroes] ([ID])
GO
ALTER TABLE [dbo].[Superheroes_Misiones] CHECK CONSTRAINT [FK__Superhero__Super__5070F446]
GO

-- %% [markdown]
-- # [FK__Superhero__Super__46E78A0C]

-- %%
ALTER TABLE [dbo].[Superheroes_Superpoderes]  WITH CHECK ADD  CONSTRAINT [FK__Superhero__Super__46E78A0C] FOREIGN KEY([SuperheroeID])
REFERENCES [dbo].[Superheroes] ([ID])
GO
ALTER TABLE [dbo].[Superheroes_Superpoderes] CHECK CONSTRAINT [FK__Superhero__Super__46E78A0C]
GO

-- %% [markdown]
-- # [FK__Superhero__Super__47DBAE45]

-- %%
ALTER TABLE [dbo].[Superheroes_Superpoderes]  WITH CHECK ADD  CONSTRAINT [FK__Superhero__Super__47DBAE45] FOREIGN KEY([SuperpoderCodigo])
REFERENCES [dbo].[Superpoderes] ([CodigoPoder])
GO
ALTER TABLE [dbo].[Superheroes_Superpoderes] CHECK CONSTRAINT [FK__Superhero__Super__47DBAE45]
GO

-- %% [markdown]
-- # [SuperHeroes]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [SuperHeroes] SET  READ_WRITE 
GO
